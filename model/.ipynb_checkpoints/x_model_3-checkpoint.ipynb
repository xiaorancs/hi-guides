# %%
from sklearn.ensemble import RandomForestClassifier

import xgboost as xgb
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split

import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 12, 4
# Out:
# /home/xiaoran/Tools/anaconda3/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
seed = 71

np.random.seed(seed)
valid_size = 0.2
LOOP = 1
ESR = 40
# XGB param
nround = 1500
#nround = 10

param = {'max_depth':6, # 基准是5 
         'eta':0.05,
         'gamma ':0.1,
         'colsample_bytree':0.8, # old 0.8
         'subsample':0.8,
         'silent':1,
         'eval_metric':'auc',
         'objective':'binary:logistic',
#          'scale_pos_weight':6
        }

# %%
# 特征以 df_12为基础，加上df_1--df_6
df_train = pd.read_csv('../data/train/orderFuture_train.csv')
df_test = pd.read_csv('../data/test/orderFuture_test.csv')

df_train_1 = pd.read_csv('../data/dataSet/df_train_1.csv')
df_test_1 = pd.read_csv('../data/dataSet/df_test_1.csv')
df_train = pd.merge(df_train,df_train_1,how='left',on='userid')
df_test = pd.merge(df_test,df_test_1,how='left',on='userid')


df_train_2 = pd.read_csv('../data/dataSet/df_train_2.csv')
df_test_2 = pd.read_csv('../data/dataSet/df_test_2.csv')
df_train = pd.merge(df_train,df_train_2,how='left',on='userid')
df_test = pd.merge(df_test,df_test_2,how='left',on='userid')


df_train_3 = pd.read_csv('../data/dataSet/df_train_3.csv')
df_test_3 = pd.read_csv('../data/dataSet/df_test_3.csv')
df_train = pd.merge(df_train,df_train_3,how='left',on='userid')
df_test = pd.merge(df_test,df_test_3,how='left',on='userid')


df_train_4 = pd.read_csv('../data/dataSet/df_train_4.csv')
df_test_4 = pd.read_csv('../data/dataSet/df_test_4.csv')
df_train = pd.merge(df_train,df_train_4,how='left',on='userid')
df_test = pd.merge(df_test,df_test_4,how='left',on='userid')

df_train_5 = pd.read_csv('../data/dataSet/df_train_5.csv')
df_test_5 = pd.read_csv('../data/dataSet/df_test_5.csv')
df_train = pd.merge(df_train,df_train_5,how='left',on='userid')
df_test = pd.merge(df_test,df_test_5,how='left',on='userid')

df_train_7 = pd.read_csv('../data/dataSet/df_train_7.csv')
df_test_7 = pd.read_csv('../data/dataSet/df_test_7.csv')
df_train = pd.merge(df_train,df_train_7,how='left',on='userid')
df_test = pd.merge(df_test,df_test_7,how='left',on='userid')

df_train_11 = pd.read_csv('../data/dataSet/df_train_11.csv')
df_test_11 = pd.read_csv('../data/dataSet/df_test_11.csv')
df_train = pd.merge(df_train,df_train_11,how='left',on='userid')
df_test = pd.merge(df_test,df_test_11,how='left',on='userid')


df_train_12 = pd.read_csv('../data/dataSet/df_train_12.csv')
df_test_12 = pd.read_csv('../data/dataSet/df_test_12.csv')
df_train = pd.merge(df_train,df_train_12,how='left',on='userid')
df_test = pd.merge(df_test,df_test_12,how='left',on='userid')

# %%
stopfeatures = ['hasOrder','actionTypeIn24Avg','actionTypeIn14Avg',
                'actionTime24CurLastDiff','actionTime59CurLastDiff','actionTimeLast0.042Days8Cnt',
                'actionTimeLast0.042Days9Cnt','actionTimeLast0.125Days8Cnt','actionTimeLast0.125Days9Cnt',
                'actionTimeLast0.25Days8Cnt','actionTimeLast0.25Days9Cnt','actionTimeLast0.5Days24Cnt',
                'actionTimeLast0.5Days59Cnt','actionTimeLast0.5Days9Cnt','actionTimeLast15Days24Cnt',
                'actionTimeLast15Days59Cnt','actionTimeLast1Days24Cnt','actionTimeLast1Days59Cnt',
                'actionTimeLast1Days9Cnt','actionTimeLast3Days24Cnt','actionTimeLast3Days59Cnt',
                'actionTimeLast3Days9Cnt','actionTimeLast5Days24Cnt','actionTimeLast5Days59Cnt',
                'actionTimeLast7Days24Cnt','actionTimeLast7Days59Cnt','actionTimeLast5Days9Cnt',
                 # df_train_6
                'actionTime24LastFirstDiffRate','actionType8Cnt','actionTypeIn14Cnt','actionTime24CurFirstDiff',
                'actionType3Cnt_actionCnt_rate','actionTypeIn24Cnt','actionTime24LastFirstDiff',
                'actionTypeIn29Cnt','actionTypeCnt','actionType4Cnt','actionType2Cnt',
                'actionType3Cnt','actionTypeIn29Cnt_actionCnt_rate','actionTypeIn14Cnt_actionCnt_rate',
                'actionType9Cnt','actionTypeIn14Avg','actionTypeIn59Avg','actionTypeIn29Avg','actionTypeIn24Avg',
                # df_train_7
                'type4DiffTimeAvg','typeDiff8TimeMaxSubAvg','type4Last3DiffTime','type2Last2DiffTime',
                'type9DiffTimeAvg','typeDiff2TimeMaxSubAvg','type7Last2DiffTime','typeDiff4TimeAvgSubMin',
                'type8Last2DiffTime','type4Last2DiffTime','typeDiff7TimeMaxSubMin','typeDiff8TimeAvgSubMin',
                'type3DiffTimeMax','type2DiffTimeAvg','type3Last2DiffTime','type2DiffTimeMin',
                'typeDiff2TimeAvgSubMin','type8Last1DiffTime','type8DiffTimeAvg','type8DiffTimeMin',
                'type3DiffTimeAvg','type2DiffTimeMax','type4DiffTimeMax','typeDiff3TimeMaxSubMin',
                'typeDiff8TimeMaxSubMin','type8Last3DiffTime','typeDiff2TimeMaxSubMin','type7Last3DiffTime',
                'typeDiff4TimeMaxSubMin','typeDiff7TimeAvgSubMin','type2Last3DiffTime','typeDiff3TimeAvgSubMin',
                'type9DiffTimeMax','type2Last1DiffTime','type4Last1DiffTime','typeDiff9TimeAvgSubMin',
                'type3DiffTimeMin','type3Last1DiffTime','type9Last2DiffTime','type3Last3DiffTime',
                'type4DiffTimeMin','type9Last3DiffTime','type9DiffTimeMin','typeDiff9TimeMaxSubAvg',
                'type9Last1DiffTime','typeDiff9TimeMaxSubMin',
                # df_train_8
                'actionTimeLast0.042Days1Cnt','actionTimeLast15Days2Cnt','actionTimeLast15Days8Cnt',
                'actionTimeLast0.5Days6Cnt','actionTimeLast0.25Days5Cnt','actionTimeLast0.25Days6Cnt',
                 'actionTimeLast0.125Days1Cnt','actionTimeLast0.5Days1Cnt','actionTimeLast0.125Days59Cnt',
                 'actionTimeLast15Days9Cnt','actionTimeLast5Days2Cnt','actionTimeLast7Days8Cnt',
                 'actionTimeLast7Days7Cnt','actionTimeLast7Days3Cnt','actionTimeLast7Days4Cnt',
                 'actionTimeLast5Days4Cnt','actionTimeLast3Days4Cnt','actionTimeLast7Days2Cnt',
                 'actionTimeLast1Days8Cnt','actionTimeLast0.5Days7Cnt','actionTimeLast3Days3Cnt',
                 'actionTimeLast3Days2Cnt','actionTimeLast1Days3Cnt','actionTimeLast0.125Days4Cnt',
                 'actionTimeLast0.125Days7Cnt','actionTimeLast5Days8Cnt','actionTimeLast1Days4Cnt',
                 'actionTimeLast0.042Days4Cnt','actionTimeLast0.25Days7Cnt','actionTimeLast3Days8Cnt',
                 'actionTimeLast0.042Days3Cnt','actionTimeLast3Days7Cnt','actionTimeLast0.5Days8Cnt',
                 'actionTimeLast5Days3Cnt','actionTimeLast0.125Days3Cnt','actionTimeLast1Days7Cnt',
                 'actionTimeLast0.5Days3Cnt','actionTimeLast0.125Days24Cnt','actionTimeLast1Days2Cnt',
                 'actionTimeLast0.125Days2Cnt','actionTimeLast0.25Days3Cnt','actionTimeLast5Days7Cnt',
                 'actionTimeLast0.042Days2Cnt','actionTimeLast0.5Days4Cnt','actionTimeLast7Days9Cnt',
                 'actionTimeLast0.5Days2Cnt','actionTimeLast5Days9Cnt','actionTimeLast0.25Days4Cnt',
                 'actionTimeLast0.25Days2Cnt','actionTimeLast3Days9Cnt','actionTimeLast1Days9Cnt',
                 'actionTimeLast0.25Days24Cnt','actionTimeLast0.125Days8Cnt','actionTimeLast0.125Days9Cnt',
                 'actionTimeLast0.25Days59Cnt','actionTimeLast0.5Days59Cnt','actionTimeLast0.042Days9Cnt',
                 'actionTimeLast0.042Days8Cnt','actionTimeLast0.25Days8Cnt','actionTimeLast1Days59Cnt',
                # df_train_10
                'type7Last2Time','type2Last2Time','type9Last1Time','type8Last2Time','type2Last3Time',
                'type7Last3Time','type3Last3Time','type4Last2Time','type4Last3Time','type3Last2Time',
                'type8Last3Time','type9Last2Time','type9Last3Time',]

# %%
goodfeature = list(df_test.columns[1:])

for f in stopfeatures:
    if f in goodfeature:
        goodfeature.remove(f)

# %%
# 设置特征数据，去除id数据，不能进行预测
features = goodfeature

label = 'orderType'

len(features)
# Out:
# 406

# %%
def split_train_valid(df_train,test_size=0.2):
    '''
    k-fold交叉验证,默认k=10
    df_train:训练数据
    '''
    X_train, X_vali, y_train, y_vali = train_test_split(df_train[features], df_train[label], test_size=test_size, random_state=40000)
    #added some parameters
    
#     dtrain = df_train.iloc[train_list]
#     dvali =  df_train.iloc[vali_list]
    
    dtrain = xgb.DMatrix(X_train,label=y_train)
    dvalid = xgb.DMatrix(X_vali,label=y_vali)
    watchlist = [(dtrain, 'train'),(dvalid, 'valid')]
    
    return dtrain, dvalid, watchlist

# %%
models = []
for i in range(LOOP):
    print('LOOP',i)
#     dbuild, dvalid, watchlist = split_build_valid(df_train)
    dbuild, dvalid, watchlist = split_train_valid(df_train,test_size=0.2)
        
    model = xgb.train(param, dbuild, nround, watchlist,early_stopping_rounds=ESR,verbose_eval=5)
    models.append(model)
    # VALID
    valid_yhat = model.predict(dvalid,ntree_limit=model.best_iteration)
    print('Valid Mean:---------------------->', np.mean(valid_yhat))
    del dbuild, dvalid, watchlist
# Out:
# LOOP 0
# [0]	train-auc:0.878367	valid-auc:0.870022
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 40 rounds.
# [5]	train-auc:0.928247	valid-auc:0.921523
# [10]	train-auc:0.932293	valid-auc:0.924923
# [15]	train-auc:0.934987	valid-auc:0.92853
# [20]	train-auc:0.939629	valid-auc:0.931776
# [25]	train-auc:0.942726	valid-auc:0.934566
# [30]	train-auc:0.945731	valid-auc:0.936388
# [35]	train-auc:0.948879	valid-auc:0.939449
# [40]	train-auc:0.951821	valid-auc:0.942081
# [45]	train-auc:0.954648	valid-auc:0.944007
# [50]	train-auc:0.957085	valid-auc:0.945522
# [55]	train-auc:0.959408	valid-auc:0.947146
# [60]	train-auc:0.961559	valid-auc:0.948287
# [65]	train-auc:0.963976	valid-auc:0.949572
# [70]	train-auc:0.965519	valid-auc:0.950469
# [75]	train-auc:0.967187	valid-auc:0.951466
# [80]	train-auc:0.968384	valid-auc:0.952222
# [85]	train-auc:0.969443	valid-auc:0.952581
# [90]	train-auc:0.970532	valid-auc:0.953293
# [95]	train-auc:0.971952	valid-auc:0.954182
# [100]	train-auc:0.972953	valid-auc:0.954937
# [105]	train-auc:0.973891	valid-auc:0.955401
# [110]	train-auc:0.974783	valid-auc:0.955748
# [115]	train-auc:0.975637	valid-auc:0.956278
# [120]	train-auc:0.976776	valid-auc:0.956595
# [125]	train-auc:0.977696	valid-auc:0.956866
# [130]	train-auc:0.978392	valid-auc:0.957219
# [135]	train-auc:0.979139	valid-auc:0.957615
# [140]	train-auc:0.979877	valid-auc:0.957945
# [145]	train-auc:0.980737	valid-auc:0.95861
# [150]	train-auc:0.981399	valid-auc:0.958971
# [155]	train-auc:0.982194	valid-auc:0.958967
# [160]	train-auc:0.98303	valid-auc:0.959387
# [165]	train-auc:0.983709	valid-auc:0.95967
# [170]	train-auc:0.984275	valid-auc:0.959918
# [175]	train-auc:0.984874	valid-auc:0.960146
# [180]	train-auc:0.985481	valid-auc:0.960577
# [185]	train-auc:0.985817	valid-auc:0.960844
# [190]	train-auc:0.986185	valid-auc:0.961134
# [195]	train-auc:0.986497	valid-auc:0.961312
# [200]	train-auc:0.986962	valid-auc:0.961612
# [205]	train-auc:0.987464	valid-auc:0.961804
# [210]	train-auc:0.987794	valid-auc:0.961908
# [215]	train-auc:0.988139	valid-auc:0.962082
# [220]	train-auc:0.988568	valid-auc:0.962126
# [225]	train-auc:0.989027	valid-auc:0.962222
# [230]	train-auc:0.989378	valid-auc:0.962323
# [235]	train-auc:0.989629	valid-auc:0.96246
# [240]	train-auc:0.990127	valid-auc:0.962806
# [245]	train-auc:0.990384	valid-auc:0.962844
# [250]	train-auc:0.990739	valid-auc:0.962823
# [255]	train-auc:0.991067	valid-auc:0.962879
# [260]	train-auc:0.99135	valid-auc:0.962922
# [265]	train-auc:0.991696	valid-auc:0.962959
# [270]	train-auc:0.991952	valid-auc:0.962914
# [275]	train-auc:0.992229	valid-auc:0.96317
# [280]	train-auc:0.992465	valid-auc:0.963174
# [285]	train-auc:0.992749	valid-auc:0.963125
# [290]	train-auc:0.992997	valid-auc:0.96327
# [295]	train-auc:0.993222	valid-auc:0.963473
# [300]	train-auc:0.993508	valid-auc:0.963477
# [305]	train-auc:0.993694	valid-auc:0.96351
# [310]	train-auc:0.993867	valid-auc:0.963658
# [315]	train-auc:0.99406	valid-auc:0.963609
# [320]	train-auc:0.994307	valid-auc:0.963583
# [325]	train-auc:0.994523	valid-auc:0.963694
# [330]	train-auc:0.994725	valid-auc:0.963698
# [335]	train-auc:0.994873	valid-auc:0.963724
# [340]	train-auc:0.995055	valid-auc:0.963788
# [345]	train-auc:0.995177	valid-auc:0.963836
# [350]	train-auc:0.995366	valid-auc:0.963864
# [355]	train-auc:0.995537	valid-auc:0.964029
# [360]	train-auc:0.995617	valid-auc:0.964123
# [365]	train-auc:0.995744	valid-auc:0.96411
# [370]	train-auc:0.9959	valid-auc:0.96424
# [375]	train-auc:0.996013	valid-auc:0.964244
# [380]	train-auc:0.996169	valid-auc:0.964391
# [385]	train-auc:0.996286	valid-auc:0.964468
# [390]	train-auc:0.996377	valid-auc:0.964397
# [395]	train-auc:0.996521	valid-auc:0.964347
# [400]	train-auc:0.996665	valid-auc:0.96433
# [405]	train-auc:0.996773	valid-auc:0.964336
# [410]	train-auc:0.996884	valid-auc:0.964326
# [415]	train-auc:0.997015	valid-auc:0.964276
# [420]	train-auc:0.997136	valid-auc:0.964263
# [425]	train-auc:0.997225	valid-auc:0.964263
# Stopping. Best iteration:
# [387]	train-auc:0.996337	valid-auc:0.964521
#
# Valid Mean:----------------------> 0.152141

# %%
# 计算特征重要程度
import operator
importance = model.get_fscore()
importance = sorted(importance.items(), key=operator.itemgetter(1),reverse=True)
print(len(importance))

importance[:100]

# feat_imp = pd.Series(model.get_fscore()).sort_values(ascending=False)
# feat_imp.plot(kind='bar', title='Feature Importances')
# plt.ylabel('Feature Importance Score')
# Out:
# 388
# [('actionTime_max_diff_6_5', 512),
#  ('type5Last2DiffTime', 277),
#  ('actionTime_max_diff_7_6', 264),
#  ('actionTime_max_diff_1_m', 245),
#  ('actionType_rank_diff_std', 229),
#  ('actionTime_max_diff_5_m', 207),
#  ('actionTime_hour_mean', 195),
#  ('type56789Last3DiffTime', 193),
#  ('actionTime_skew', 191),
#  ('type56789Last4DiffTime', 188),
#  ('type56789Last2DiffTime', 178),
#  ('type6DiffTimeMin', 166),
#  ('last2DiffTime', 159),
#  ('type56789DiffTimeMin', 155),
#  ('last3DiffTime', 154),
#  ('type56789Last5DiffTime', 150),
#  ('type6Last2DiffTime', 144),
#  ('actionType_rank_diff_mean', 142),
#  ('action_006_rate', 140),
#  ('actionTime_hour_std', 134),
#  ('action_5_6_rara', 132),
#  ('actionTime_std_006', 130),
#  ('actionTime_max_diff_4_m', 129),
#  ('action_005_rate', 122),
#  ('action_001_rate', 121),
#  ('actionTime_rank_diff_std', 119),
#  ('actionTime_max_diff_6_m', 117),
#  ('actiontime_orderTime_diff', 116),
#  ('actionTime_std_001', 115),
#  ('last6DiffTime', 115),
#  ('last4DiffTime', 114),
#  ('type1Last2DiffTime', 114),
#  ('last1Type', 109),
#  ('actionTime_rank_diff_1', 108),
#  ('type6Last3DiffTime', 107),
#  ('actionTime_rank_diff_mean', 105),
#  ('type1Last3DiffTime', 105),
#  ('actionTime_std_005', 102),
#  ('actionType_cv', 102),
#  ('city_mean', 102),
#  ('type5Last3DiffTime', 101),
#  ('long_mean_all', 101),
#  ('type1DiffTimeMin', 100),
#  ('actionTime_rank_diff_sum', 100),
#  ('diffTimeMin', 96),
#  ('actionTime_min_005', 94),
#  ('typeDiff6TimeMaxSubAvg', 93),
#  ('last5DiffTime', 93),
#  ('actionTime_rank_std', 91),
#  ('orderTypeContain1', 90),
#  ('actionTime_min_006', 89),
#  ('actionTime_max_diff_2_m', 89),
#  ('actionType_rank_diff_2', 88),
#  ('last8DiffTime', 88),
#  ('last7DiffTime', 87),
#  ('actionType_mean', 87),
#  ('last1DiffTime', 87),
#  ('action_5_6_rate', 87),
#  ('actionType_std', 84),
#  ('type5DiffTimeMin', 84),
#  ('actionType_skew', 83),
#  ('actionTime_rank_diff_2', 81),
#  ('actionTime_min_001', 81),
#  ('province_cnt', 80),
#  ('actionType_rank_diff_1', 79),
#  ('age_province_cnt', 79),
#  ('last10DiffTime', 78),
#  ('actionTime_rank_diff_3', 76),
#  ('userid_actionTime_max_hour', 72),
#  ('action_004_rate', 71),
#  ('action_5_6_diff', 68),
#  ('last9DiffTime', 68),
#  ('action_cnt_006', 68),
#  ('actionTime_6_last', 67),
#  ('actionTime_max_006_hour', 66),
#  ('last15DiffTime', 66),
#  ('type1Last4DiffTime', 65),
#  ('actionTime_hour_max', 65),
#  ('actionTime_max_005_hour', 65),
#  ('wrds_long_mean', 65),
#  ('typeDiff6TimeAvgSubMin', 65),
#  ('actionTime_rank_diff_10', 65),
#  ('actionTime_rank_diff_8', 65),
#  ('actionType_rank_diff_3', 64),
#  ('actionTime_1_last', 64),
#  ('tags_long_mean', 64),
#  ('actionTime_rank_diff_4', 64),
#  ('typeDiff5TimeAvgSubMin', 62),
#  ('actionTime_std', 62),
#  ('last11DiffTime', 61),
#  ('age_province', 59),
#  ('actionTime_rank_diff_5', 59),
#  ('actionTime_max_diff_8_m', 59),
#  ('last12DiffTime', 59),
#  ('actionType_rank_diff_4', 58),
#  ('last13DiffTime', 58),
#  ('actionTime_rank_diff_6', 58),
#  ('province', 58),
#  ('actionTime_rank_diff_9', 58),
#  ('type1Last5DiffTime', 57)]

# %%
models = []
for i in range(LOOP):
    print('LOOP',i)
    dbuild, dvalid, watchlist = split_train_valid(df_train,test_size=0.1)
    dtrain = xgb.DMatrix(df_train[features],label=df_train[label])
    
    nround = 437 # 在验证的基础上加上20轮左右
    model = xgb.train(param, dtrain,nround,watchlist,verbose_eval=10)
    models.append(model)
    # VALID
    valid_yhat = model.predict(dvalid,ntree_limit=model.best_iteration)
    print('Valid Mean:---------------------->', np.mean(valid_yhat))
    del dbuild, dvalid, watchlist

#==============================================================================
print('test')
#==============================================================================

dtest  = xgb.DMatrix(df_test[features])
proba_test = pd.DataFrame()
proba_test['userid'] = df_test['userid']
proba_test['orderType'] = [0 for i in range(len(df_test))]
for model in models:
    proba_test['orderType'] += model.predict(dtest)
proba_test['orderType'] /= LOOP
# Out:
# LOOP 0
# [0]	train-auc:0.893524	valid-auc:0.898153
# [10]	train-auc:0.930216	valid-auc:0.930491
# [20]	train-auc:0.937919	valid-auc:0.937382
# [30]	train-auc:0.944921	valid-auc:0.942025
# [40]	train-auc:0.94981	valid-auc:0.945332
# [50]	train-auc:0.955322	valid-auc:0.951045
# [60]	train-auc:0.960182	valid-auc:0.957018
# [70]	train-auc:0.963636	valid-auc:0.960628
# [80]	train-auc:0.966851	valid-auc:0.963815
# [90]	train-auc:0.969396	valid-auc:0.966727
# [100]	train-auc:0.971988	valid-auc:0.969487
# [110]	train-auc:0.973971	valid-auc:0.971322
# [120]	train-auc:0.975756	valid-auc:0.973195
# [130]	train-auc:0.977209	valid-auc:0.974604
# [140]	train-auc:0.978599	valid-auc:0.976041
# [150]	train-auc:0.980285	valid-auc:0.978076
# [160]	train-auc:0.981743	valid-auc:0.979818
# [170]	train-auc:0.982788	valid-auc:0.980966
# [180]	train-auc:0.983622	valid-auc:0.981983
# [190]	train-auc:0.984708	valid-auc:0.983114
# [200]	train-auc:0.98554	valid-auc:0.983987
# [210]	train-auc:0.986417	valid-auc:0.98492
# [220]	train-auc:0.987249	valid-auc:0.98597
# [230]	train-auc:0.988001	valid-auc:0.986776
# [240]	train-auc:0.988683	valid-auc:0.987589
# [250]	train-auc:0.989308	valid-auc:0.988266
# [260]	train-auc:0.989936	valid-auc:0.988841
# [270]	train-auc:0.990424	valid-auc:0.989382
# [280]	train-auc:0.990991	valid-auc:0.990025
# [290]	train-auc:0.991476	valid-auc:0.990588
# [300]	train-auc:0.992017	valid-auc:0.991078
# [310]	train-auc:0.992405	valid-auc:0.991465
# [320]	train-auc:0.992806	valid-auc:0.991925
# [330]	train-auc:0.993209	valid-auc:0.992353
# [340]	train-auc:0.993576	valid-auc:0.992725
# [350]	train-auc:0.993871	valid-auc:0.993073
# [360]	train-auc:0.994322	valid-auc:0.993598
# [370]	train-auc:0.994614	valid-auc:0.994008
# [380]	train-auc:0.994881	valid-auc:0.994321
# [390]	train-auc:0.995148	valid-auc:0.994606
# [400]	train-auc:0.995348	valid-auc:0.994848
# [410]	train-auc:0.995606	valid-auc:0.995181
# [420]	train-auc:0.995886	valid-auc:0.995602
# [430]	train-auc:0.996166	valid-auc:0.995816
# Valid Mean:----------------------> 0.154388
# test

# %%
# 写入结果文件
proba_test.to_csv('../result/test_submussion_2.csv',index=False,index_label=False)
